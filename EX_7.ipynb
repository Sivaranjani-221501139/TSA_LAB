# %% [markdown]
# <a href="https://colab.research.google.com/github/SubashiniB181203/Time-Series-Analysis-Lab/blob/main/221501145_TSA_exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

df = pd.read_csv(r"C:\Users\siva\Downloads\1. Weather Data.csv", parse_dates=['Date'], index_col='Date')
print(df.head())

result = seasonal_decompose(df['Temperature'], model='additive', period=365)  

plt.figure(figsize=(12, 8))

# Plot the original time series
plt.subplot(4, 1, 1)
plt.plot(df['Temperature'], label='Original Data')
plt.title('Original Temperature Time Series')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')

# Plot the trend component
plt.subplot(4, 1, 2)
plt.plot(result.trend, label='Trend', color='orange')
plt.title('Trend Component')
plt.xlabel('Date')
plt.ylabel('Trend')

# Plot the seasonal component
plt.subplot(4, 1, 3)
plt.plot(result.seasonal, label='Seasonality', color='green')
plt.title('Seasonal Component')
plt.xlabel('Date')
plt.ylabel('Seasonality')

# Plot the residual component
plt.subplot(4, 1, 4)
plt.plot(result.resid, label='Residuals', color='red')
plt.title('Residual Component')
plt.xlabel('Date')
plt.ylabel('Residual')

plt.tight_layout()
plt.show()
# Out:
#                   Temperature  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date
# 01-01-2012 00:00         -1.8              -3.9         86                4
# 01-01-2012 01:00         -1.8              -3.7         87                4
# 01-01-2012 02:00         -1.8              -3.4         89                7
# 01-01-2012 03:00         -1.5              -3.2         88                6
# 01-01-2012 04:00         -1.5              -3.3         88                7
#
#                   Visibility_km  Press_kPa               Weather
# Date
# 01-01-2012 00:00            8.0     101.24                   Fog
# 01-01-2012 01:00            8.0     101.24                   Fog
# 01-01-2012 02:00            4.0     101.26  Freezing Drizzle,Fog
# 01-01-2012 03:00            4.0     101.27  Freezing Drizzle,Fog
# 01-01-2012 04:00            4.8     101.23                   Fog
